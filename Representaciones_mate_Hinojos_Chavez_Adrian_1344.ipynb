# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051281344-del/Mate-Razonamiento-1344-Adrian-Hinojos-/blob/main/Representaciones_mate_Hinojos_Chavez_Adrian_1344.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  #### Adrian Hinojos NL= 25 Fecha 15Abr/26
# #### Problema 1
# Problema 1: La suma de un número más 9 es igual a 21Para resolver esto, seguimos un proceso de traducción algebraica:Definir la variable: Sea $x$ el número desconocido.Plantear la ecuación: "La suma de un número ($x$) más 9 ($+ 9$) es igual a 21 ($= 21$)".$$x + 9 = 21$$Despejar la variable: Para dejar sola a la $x$, restamos 9 en ambos lados de la igualdad:$$x = 21 - 9$$Resultado:$$x = 12$$

# %%
# Definimos los valores conocidos
# resultado_total = 21
# numero_sumado = 9
resultado_total = int(input("Ingrese el resultado total: "))
numero_conocido = int(input("Ingrese el número sumado: "))
# Despejamos x: x = 21 - 9
x = resultado_total - numero_conocido
# Imprimimos el resultado
print(f"El número desconocido es: {x}")
#

print(f"El número buscado en el Problema 1 es: {incognita}")
# Out:
# El número buscado en el Problema 1 es: 12

# %% [markdown]
# #### Adrian Hinojos NL= 25 Fecha 15Abr/26
# #### Problema 2
# Problema 2: Edades de Pedro y su hermanaAquí manejamos una relación entre dos incógnitas:Definir las variables:Edad de la hermana: $x$Edad de Pedro: $2x$ (ya que es el doble).Plantear la ecuación: "La suma de las dos edades es 36".$$x + 2x = 36$$Simplificar: Sumamos los términos semejantes:$$3x = 36$$Despejar la variable: El 3 que multiplica a la $x$ pasa dividiendo:$$x = \frac{36}{3}$$$$x = 12$$Resultado final:Hermana ($x$): 12 años.Pedro ($2x$): 24 años.

# %%
# Definimos el total de la suma de edades
# total_suma = 36
suma_total = int(input("Ingrese la suma total  : "))

# La ecuación es x + 2x = 36 -> 3x = 36
# Por lo tanto, dividimos el total entre 3 para hallar la edad de la hermana
edad_hermana = total_suma / 3
edad_pedro = edad_hermana * 2

print(f"La hermana tiene: {int(edad_hermana)} años")
print(f"Pedro tiene: {int(edad_pedro)} años")
# Out:
# La hermana tiene: 12 años
# Pedro tiene: 24 años
